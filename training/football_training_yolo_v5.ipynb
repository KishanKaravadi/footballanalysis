# %%
# %pip install ultralytics
# %pip install roboflow

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="6nwvKwNPx7FEW4SlWRJj")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train')\

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid')

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:847, in move(src, dst, copy_function)
#     846 try:
# --> 847     os.rename(src, real_dst)
#     848 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'football-players-detection-1/train' -> 'football-players-detection-1/football-players-detection-1/train/train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import shutil
# ----> 3 shutil.move('football-players-detection-1/train',
#       4             'football-players-detection-1/football-players-detection-1/train')\
#       6 shutil.move('football-players-detection-1/valid',
#       7             'football-players-detection-1/football-players-detection-1/valid')
#       9 shutil.move('football-players-detection-1/test',
#      10             'football-players-detection-1/football-players-detection-1/test')
#
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:867, in move(src, dst, copy_function)
#     865         rmtree(src)
#     866     else:
# --> 867         copy_function(src, real_dst)
#     868         os.unlink(src)
#     869 return real_dst
#
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:475, in copy2(src, dst, follow_symlinks)
#     472         else:
#     473             raise
# --> 475 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476 copystat(src, dst, follow_symlinks=follow_symlinks)
#     477 return dst
#
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'football-players-detection-1/train'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5su.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov5su.pt to 'yolov5su.pt'...
# 100%|██████████████████████████████████████| 17.7M/17.7M [00:00<00:00, 39.3MB/s]
# New https://pypi.org/project/ultralytics/8.2.75 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.74 🚀 Python-3.12.4 torch-2.4.0 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# engine/trainer: task=detect, mode=train, model=yolov5su.pt, data=/home/kishan/code/footballanalysis/training/football-players-detection-1/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train5, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train5
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      3520  ultralytics.nn.modules.conv.Conv             [3, 32, 6, 2, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     18816  ultralytics.nn.modules.block.C3              [64, 64, 1]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    115712  ultralytics.nn.modules.block.C3              [128, 128, 2]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  3    625152  ultralytics.nn.modules.block.C3              [256, 256, 3]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1182720  ultralytics.nn.modules.block.C3              [512, 512, 1]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    361984  ultralytics.nn.modules.block.C3              [512, 256, 1, False]
#  14                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  21                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1   1182720  ultralytics.nn.modules.block.C3              [512, 512, 1, False]
#  24        [17, 20, 23]  1   2117596  ultralytics.nn.modules.head.Detect           [4, [128, 256, 512]]
# YOLOv5s summary: 262 layers, 9,123,740 parameters, 9,123,724 gradients, 24.0 GFLOPs
#
# Transferred 421/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# /home/kishan/miniconda3/envs/foot/lib/python3.12/site-packages/ultralytics/engine/trainer.py:269: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# train: Scanning /home/kishan/code/footballanalysis/training/football-players-det
# val: Scanning /home/kishan/code/footballanalysis/training/football-players-detec
# Plotting labels to runs/detect/train5/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0005), 75 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train5
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.09G      1.528      1.903     0.8759        144        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.454       0.31       0.25      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         4G      1.391      0.869     0.8278        114        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.764      0.489      0.515      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.09G       1.36     0.7802     0.8233        178        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.783      0.449      0.528      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         4G      1.294     0.7114     0.8176        199        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.847      0.448      0.566      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.99G      1.332     0.7041     0.8195        185        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.806      0.517      0.604       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.05G      1.243     0.6534     0.8154        168        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905        0.6      0.595      0.627      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.05G      1.249     0.6478     0.8129        228        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.712      0.555      0.626      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.15G      1.194     0.6159     0.8097        147        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.832      0.662      0.704      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         4G      1.129     0.5754     0.8063        161        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.855      0.589      0.689      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      3.98G      1.138     0.5705     0.8053        186        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905        0.6      0.629       0.69      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.13G       1.17     0.5761     0.8066        112        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.726      0.677      0.715       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100       4.2G      1.087     0.5439     0.8021        188        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.767      0.655      0.704      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.18G      1.127     0.5539     0.8034        204        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.823      0.658      0.713      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.09G      1.084     0.5316     0.8027        149        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.745      0.702      0.726       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.18G      1.102     0.5361     0.8019        158        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.806      0.665      0.719      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.12G      1.082     0.5386     0.8026        161        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.767      0.586      0.664      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      3.98G       1.06     0.5312     0.7994        162        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.824      0.654      0.712      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.99G       1.07     0.5192     0.7965        146        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.817      0.692      0.741       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.17G      1.082      0.529     0.8021        194        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.855      0.622      0.701      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         4G      1.148     0.5681     0.8053        111        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.772      0.687      0.729      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      3.98G      1.108     0.5714     0.8011        221        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.853      0.653      0.735      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.15G      1.067     0.5362     0.7987        102        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.872      0.673      0.747      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.16G       1.01     0.4922     0.7958         93        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.93      0.635      0.725      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.17G     0.9936     0.4793      0.793        121        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.849      0.664      0.728      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.16G      1.004     0.4827     0.7946        166        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.849      0.658      0.729      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.13G      1.005      0.484     0.7962        109        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.906      0.658      0.725      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100         4G      1.013     0.4867     0.7946        132        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.748      0.676      0.725      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.15G     0.9781     0.4753     0.7941         83        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.848      0.655      0.739       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100         4G      0.985     0.4691     0.7926         90        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.899       0.64      0.748       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      3.96G      1.003     0.4815     0.7944        183        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.864      0.668      0.722      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.12G       1.04     0.4922     0.7938        190        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.928      0.664      0.739      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.18G     0.9825     0.4632      0.791        133        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.929      0.693      0.767      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      3.98G     0.9923     0.4649     0.7933        125        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.797       0.71      0.745      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.12G     0.9301     0.4405      0.793        147        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.805      0.728      0.769      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.14G     0.9588     0.4484     0.7906        150        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.765      0.718      0.751        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      3.98G     0.9333     0.4447     0.7889         99        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.822      0.683      0.748      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      3.99G      0.952     0.4527     0.7919        124        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.855      0.725      0.761      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.15G     0.9617     0.4483     0.7915        186        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.916       0.68      0.766      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.08G     0.9333     0.4395     0.7898        130        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.85      0.698      0.771      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      4.17G     0.9295      0.439     0.7895        118        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.851        0.7      0.752        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      4.02G     0.9374     0.4423     0.7893        132        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.849      0.725      0.767      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      3.99G     0.9212     0.4322     0.7914        138        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.885      0.713       0.76      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      3.99G     0.9427     0.4421     0.7874        141        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.87      0.676      0.751      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      4.19G     0.9284     0.4351     0.7893        137        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.818      0.693      0.746      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      4.14G     0.9756     0.4596     0.7886        159        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.842      0.727      0.775      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      4.14G     0.9315     0.4345     0.7895        195        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.736      0.695      0.726      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100         4G     0.9087     0.4244     0.7887        209        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.829      0.697       0.76      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      4.23G     0.9193     0.4268     0.7879        142        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.819      0.705       0.77      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      4.13G     0.9094     0.4283      0.789        233        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.914      0.711      0.772      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      4.14G     0.8938     0.4185     0.7862        200        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.959      0.715      0.784      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100         4G     0.9097     0.4273     0.7878        179        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.836      0.709      0.787      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      4.14G     0.9162     0.4272     0.7883        170        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.797      0.751      0.782      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      4.16G     0.8985     0.4211     0.7866        105        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.839      0.744      0.776      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      4.13G     0.9152     0.4299     0.7866        104        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.798      0.713      0.762      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      4.04G     0.8791     0.4138     0.7852        174        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.842      0.632      0.741      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      4.13G     0.9222     0.4263     0.7891        154        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.928      0.692      0.777      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.06G     0.9111     0.4187     0.7852        158        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.883      0.731      0.781      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      4.17G     0.8659     0.4076     0.7845        127        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.942      0.696      0.776      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      4.13G     0.8711     0.4101     0.7855        158        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.788      0.688      0.758      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100         4G     0.8752     0.4074     0.7835        207        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.883      0.711       0.78      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.97G     0.8719     0.4054      0.782        115        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.914      0.681      0.772      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100         4G     0.8767     0.4009     0.7852        229        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.828      0.713      0.771      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100         4G     0.8482     0.3976     0.7836        214        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.843      0.752      0.788      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.11G     0.8381     0.3941      0.783        168        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.838      0.752      0.784      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100         4G     0.8569        0.4     0.7844         93        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.84      0.707      0.772      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.15G     0.8574     0.4018     0.7836        196        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.865      0.719      0.773      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.18G     0.8458     0.4011     0.7853        151        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.822       0.75      0.782       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.98G     0.8392     0.3964      0.783        136        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.889      0.668      0.764      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.15G     0.8308     0.3979     0.7839        105        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.807      0.714      0.785      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.99G     0.8647     0.4057     0.7849        204        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.853        0.7      0.771      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.01G     0.8601      0.405     0.7819        248        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.839      0.717      0.776      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      4.13G     0.8337     0.3943     0.7811         80        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.871      0.725      0.797      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.99G     0.8217     0.3858     0.7815        103        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.834      0.699      0.781      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      3.96G     0.8269     0.3837     0.7826        185        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.86      0.749      0.801      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      4.07G     0.8112     0.3796     0.7819        123        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.891       0.75      0.813      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      4.16G     0.8057     0.3815     0.7817        138        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.915      0.688      0.776      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      4.07G     0.8129     0.3784     0.7812        172        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.813      0.738      0.788      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.98G     0.8208     0.3839      0.781        158        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.871      0.721      0.778      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100         4G     0.8114     0.3822     0.7799        127        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.93      0.733      0.807      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100         4G     0.8107     0.3784     0.7809        104        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.838      0.747      0.787      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      4.14G     0.7883     0.3713     0.7806        230        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.826      0.749      0.787      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.97G     0.7695     0.3679     0.7784        104        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.841      0.733      0.786      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      4.07G     0.7874     0.3753     0.7814        184        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.894      0.731      0.795      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      4.17G     0.7984     0.3735     0.7792        105        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.842      0.718      0.783      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      4.18G     0.7845     0.3676     0.7771        261        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.845      0.753      0.797       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100       4.1G     0.7754     0.3645     0.7794        141        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.875      0.746       0.81       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.13G     0.7795     0.3703     0.7785        152        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.865       0.72      0.781      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100       4.1G     0.7972     0.3699     0.7787        175        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.851       0.74      0.796      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      3.98G     0.7654     0.3625     0.7778        179        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.858      0.746      0.805      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.07G     0.7654      0.361     0.7786        183        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.854      0.753      0.802      0.539
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.03G     0.7406     0.3618     0.7782         91        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.927      0.708      0.787      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.16G     0.7111     0.3508     0.7783         92        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.862      0.752      0.785      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.02G      0.705     0.3441     0.7793         94        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.94       0.75      0.809      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100         4G     0.6913     0.3401     0.7779         93        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.867      0.741      0.794      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.02G     0.6933     0.3387      0.775         91        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.871      0.746      0.796      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.16G     0.6853      0.336     0.7768         96        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.901       0.71      0.795      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.02G     0.6767     0.3336     0.7752         93        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.831      0.744       0.79      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100         4G     0.6623     0.3291     0.7773         88        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.851       0.75      0.804      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.03G     0.6871     0.3351     0.7756         96        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.866      0.751      0.817      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.01G     0.6722     0.3318     0.7748         92        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.891      0.763      0.818      0.526
#
# 100 epochs completed in 0.239 hours.
# Optimizer stripped from runs/detect/train5/weights/last.pt, 18.5MB
# Optimizer stripped from runs/detect/train5/weights/best.pt, 18.5MB
#
# Validating runs/detect/train5/weights/best.pt...
# Ultralytics YOLOv8.2.74 🚀 Python-3.12.4 torch-2.4.0 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# YOLOv5s summary (fused): 193 layers, 9,113,084 parameters, 0 gradients, 23.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.854      0.753      0.802      0.538
#                   ball         35         35      0.803      0.233      0.351      0.119
#             goalkeeper         27         27      0.866      0.926      0.976      0.698
#                 player         38        754      0.937      0.955      0.981      0.762
#                referee         38         89      0.809      0.899      0.901      0.573
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/train5
# 💡 Learn more at https://docs.ultralytics.com/modes/train
