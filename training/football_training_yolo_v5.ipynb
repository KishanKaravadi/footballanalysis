# %%
# %pip install ultralytics
# %pip install roboflow

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="6nwvKwNPx7FEW4SlWRJj")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train')\

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid')

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:847, in move(src, dst, copy_function)
#     846 try:
# --> 847     os.rename(src, real_dst)
#     848 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'football-players-detection-1/train' -> 'football-players-detection-1/football-players-detection-1/train/train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import shutil
# ----> 3 shutil.move('football-players-detection-1/train',
#       4             'football-players-detection-1/football-players-detection-1/train')\
#       6 shutil.move('football-players-detection-1/valid',
#       7             'football-players-detection-1/football-players-detection-1/valid')
#       9 shutil.move('football-players-detection-1/test',
#      10             'football-players-detection-1/football-players-detection-1/test')
#
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:867, in move(src, dst, copy_function)
#     865         rmtree(src)
#     866     else:
# --> 867         copy_function(src, real_dst)
#     868         os.unlink(src)
#     869 return real_dst
#
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:475, in copy2(src, dst, follow_symlinks)
#     472         else:
#     473             raise
# --> 475 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476 copystat(src, dst, follow_symlinks=follow_symlinks)
#     477 return dst
#
# File ~/miniconda3/envs/foot/lib/python3.12/shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'football-players-detection-1/train'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov9t.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov9t.pt to 'yolov9t.pt'...
# 100%|██████████████████████████████████████| 4.74M/4.74M [00:00<00:00, 81.4MB/s]
# Ultralytics YOLOv8.2.76 🚀 Python-3.12.4 torch-2.4.0 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# engine/trainer: task=detect, mode=train, model=yolov9t.pt, data=/home/kishan/code/footballanalysis/training/football-players-detection-1/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7872  ultralytics.nn.modules.block.ELAN1           [32, 32, 32, 16]
#   3                  -1  1     18560  ultralytics.nn.modules.block.AConv           [32, 64]
#   4                  -1  1     65216  ultralytics.nn.modules.block.RepNCSPELAN4    [64, 64, 64, 32, 3]
#   5                  -1  1     55488  ultralytics.nn.modules.block.AConv           [64, 96]
#   6                  -1  1    145824  ultralytics.nn.modules.block.RepNCSPELAN4    [96, 96, 96, 48, 3]
#   7                  -1  1    110848  ultralytics.nn.modules.block.AConv           [96, 128]
#   8                  -1  1    258432  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 128, 128, 64, 3]
#   9                  -1  1     41344  ultralytics.nn.modules.block.SPPELAN         [128, 128, 64]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    158112  ultralytics.nn.modules.block.RepNCSPELAN4    [224, 96, 96, 48, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     71360  ultralytics.nn.modules.block.RepNCSPELAN4    [160, 64, 64, 32, 3]
#  16                  -1  1     27744  ultralytics.nn.modules.block.AConv           [64, 48]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    150432  ultralytics.nn.modules.block.RepNCSPELAN4    [144, 96, 96, 48, 3]
#  19                  -1  1     55424  ultralytics.nn.modules.block.AConv           [96, 64]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    266624  ultralytics.nn.modules.block.RepNCSPELAN4    [192, 128, 128, 64, 3]
#  22        [15, 18, 21]  1    567772  ultralytics.nn.modules.head.Detect           [4, [64, 96, 128]]
# YOLOv9t summary: 917 layers, 2,006,188 parameters, 2,006,172 gradients, 7.9 GFLOPs
#
# Transferred 1303/1339 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# /home/kishan/miniconda3/envs/foot/lib/python3.12/site-packages/ultralytics/engine/trainer.py:269: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# train: Scanning /home/kishan/code/footballanalysis/training/football-players-det
# val: Scanning /home/kishan/code/footballanalysis/training/football-players-detec
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 221 weight(decay=0.0), 228 weight(decay=0.0005), 227 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.13G      1.793      2.481     0.9108        144        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905     0.0394      0.235      0.149     0.0745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.55G       1.62      1.245     0.8579        114        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.718      0.175      0.223      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100       3.8G      1.555      1.123     0.8475        178        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.702      0.219      0.235      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.16G      1.564      1.062     0.8489        199        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.834      0.251        0.3      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.78G      1.482     0.9735      0.842        185        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.639      0.332      0.351      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100       3.7G       1.45     0.9129     0.8382        168        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.653      0.357      0.399      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.85G      1.374     0.8701     0.8276        228        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.776      0.466      0.514      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.35G      1.342     0.8283     0.8277        147        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.774      0.501      0.541      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      3.38G      1.302     0.7759     0.8245        161        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.816      0.493      0.565      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      3.76G       1.33     0.7733     0.8238        186        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.836       0.52      0.588      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      3.87G      1.328     0.7514      0.824        112        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.816      0.528      0.592      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      3.85G       1.33     0.7403     0.8244        188        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.826      0.584      0.608      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      3.48G      1.337     0.7317     0.8262        204        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.838      0.567      0.611      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      3.76G       1.27     0.6867      0.821        149        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.782      0.521      0.585       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      3.68G      1.241     0.6689     0.8178        158        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.825      0.591      0.618      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      3.64G      1.238     0.6652     0.8176        161        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.836      0.552        0.6      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      3.32G      1.211     0.6512     0.8139        162        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.853      0.604      0.632      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.59G       1.22     0.6363     0.8129        146        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.859      0.603      0.651      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      3.46G       1.22     0.6345     0.8168        194        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.848      0.597      0.634      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      3.59G      1.233     0.6379     0.8156        111        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.908      0.552      0.631      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.06G       1.24     0.6378     0.8146        221        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.851      0.551       0.62      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      3.66G      1.234      0.629     0.8131        102        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.823      0.567      0.622      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      3.64G      1.167     0.5996      0.811         93        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.816      0.599      0.654      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      3.68G      1.152       0.59     0.8087        121        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.85      0.634      0.655      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      3.65G      1.148     0.5855     0.8099        166        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0